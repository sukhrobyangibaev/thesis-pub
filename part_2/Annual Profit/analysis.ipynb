# %%
import numpy as np # linear algebra
import pandas as pd # data manipulation and analysis
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization

# %%
sns.set_style('whitegrid') # set style for visualization

# %% [markdown]
# importing dataset

# %%
df = pd.read_csv('adult.data', delimiter=',')

# %% [markdown]
# # Data Understanding

# %% [markdown]
# Get the first 5 rows of the dataset.

# %%
df.head()
# Out:
#    age          workclass   fnlwgt   education   education-num
# 0   39          State-gov    77516   Bachelors              13  \
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex
# 0        Never-married        Adm-clerical   Not-in-family   White     Male  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %% [markdown]
# get randomly select 5 rows

# %%
df.sample(5)
# Out:
#        age   workclass   fnlwgt      education   education-num
# 8475    47     Private    44216        HS-grad               9  \
# 15002   52     Private    53497      Assoc-voc              11
# 7881    22     Private   291386   Some-college              10
# 28530   60   Local-gov   101110      Assoc-voc              11
# 7545    31     Private   261943   Some-college              10
#
#             marital-status        occupation    relationship    race      sex
# 8475              Divorced   Exec-managerial       Unmarried   White   Female  \
# 15002   Married-civ-spouse      Craft-repair         Husband   White     Male
# 7881         Never-married      Adm-clerical   Not-in-family   White   Female
# 28530             Divorced    Prof-specialty       Unmarried   White     Male
# 7545    Married-civ-spouse   Exec-managerial         Husband   White     Male
#
#         capital-gain   capital-loss   hours-per-week  native-country  income
# 8475               0              0               45   United-States   <=50K
# 15002              0              0               40   United-States   <=50K
# 7881               0              0               40   United-States   <=50K
# 28530              0              0               40   United-States    >50K
# 7545               0              0               40   United-States   <=50K

# %% [markdown]
# to get last 5 rows.

# %%
df.tail()
# Out:
#        age      workclass   fnlwgt    education   education-num
# 32556   27        Private   257302   Assoc-acdm              12  \
# 32557   40        Private   154374      HS-grad               9
# 32558   58        Private   151910      HS-grad               9
# 32559   22        Private   201490      HS-grad               9
# 32560   52   Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation  relationship    race      sex
# 32556   Married-civ-spouse        Tech-support          Wife   White   Female  \
# 32557   Married-civ-spouse   Machine-op-inspct       Husband   White     Male
# 32558              Widowed        Adm-clerical     Unmarried   White   Female
# 32559        Never-married        Adm-clerical     Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial          Wife   White   Female
#
#         capital-gain   capital-loss   hours-per-week  native-country  income
# 32556              0              0               38   United-States   <=50K
# 32557              0              0               40   United-States    >50K
# 32558              0              0               40   United-States   <=50K
# 32559              0              0               20   United-States   <=50K
# 32560          15024              0               40   United-States    >50K

# %% [markdown]
# df.info() method returns information about the DataFrame including the index data type and columns, non-null values, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1    workclass       32561 non-null  object
#  2    fnlwgt          32561 non-null  int64
#  3    education       32561 non-null  object
#  4    education-num   32561 non-null  int64
#  5    marital-status  32561 non-null  object
#  6    occupation      32561 non-null  object
#  7    relationship    32561 non-null  object
#  8    race            32561 non-null  object
#  9    sex             32561 non-null  object
#  10   capital-gain    32561 non-null  int64
#  11   capital-loss    32561 non-null  int64
#  12   hours-per-week  32561 non-null  int64
#  13   native-country  32561 non-null  object
#  14   income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# df.shape returns a tuple that represents the dimensions of the data frame

# %%
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# If we want to see only the variable names, then we can use the df.columns method to get all the names.

# %%
df.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' income'],
#       dtype='object')

# %% [markdown]
# df.describe() method generates descriptive statistics for us. For numeric data, the result’s index will include count, mean, std, min, max as well as lower, 50(median) and upper percentiles.

# %%
df.describe()
# Out:
#                 age        fnlwgt   education-num   capital-gain
# count  32561.000000  3.256100e+04    32561.000000   32561.000000  \
# mean      38.581647  1.897784e+05       10.080679    1077.648844
# std       13.640433  1.055500e+05        2.572720    7385.292085
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.370510e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   32561.000000     32561.000000
# mean       87.303830        40.437456
# std       402.960219        12.347429
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %% [markdown]
# For object data (e.g. strings or timestamps), the result’s index will include count, unique, top, and freq. The top is the most common value. The freq is the most common value’s frequency. Timestamps also include the first and last items.

# %%
df.describe(include='O')
# Out:
#         workclass  education       marital-status       occupation
# count       32561      32561                32561            32561  \
# unique          9         16                    7               15
# top       Private    HS-grad   Married-civ-spouse   Prof-specialty
# freq        22696      10501                14976             4140
#
#         relationship    race    sex  native-country  income
# count          32561   32561  32561           32561   32561
# unique             6       5      2              42       2
# top          Husband   White   Male   United-States   <=50K
# freq           13193   27816  21790           29170   24720

# %% [markdown]
# We can also see unique values in discrete variable using .unique() method.

# %%
df.columns.tolist()
# Out:
# ['age',
#  ' workclass',
#  ' fnlwgt',
#  ' education',
#  ' education-num',
#  ' marital-status',
#  ' occupation',
#  ' relationship',
#  ' race',
#  ' sex',
#  ' capital-gain',
#  ' capital-loss',
#  ' hours-per-week',
#  ' native-country',
#  ' income']

# %%
list(df[' workclass'].unique())
# Out:
# [' State-gov',
#  ' Self-emp-not-inc',
#  ' Private',
#  ' Federal-gov',
#  ' Local-gov',
#  ' ?',
#  ' Self-emp-inc',
#  ' Without-pay',
#  ' Never-worked']

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# When combining .isnull() method with .sum() we can sum up all the missing values for each variables.

# %%
df.isnull().sum()
# Out:
# age                0
#  workclass         0
#  fnlwgt            0
#  education         0
#  education-num     0
#  marital-status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital-gain      0
#  capital-loss      0
#  hours-per-week    0
#  native-country    0
#  income            0
# dtype: int64

# %% [markdown]
# searching for duplicates

# %%
df[df.duplicated(keep='first')]
# Out:
#        age          workclass   fnlwgt      education   education-num
# 4881    25            Private   308144      Bachelors              13  \
# 5104    90            Private    52386   Some-college              10
# 9171    21            Private   250051   Some-college              10
# 11631   20            Private   107658   Some-college              10
# 13084   25            Private   195994        1st-4th               2
# 15059   21            Private   243368      Preschool               1
# 17040   46            Private   173243        HS-grad               9
# 18555   30            Private   144593        HS-grad               9
# 18698   19            Private    97261        HS-grad               9
# 21318   19            Private   138153   Some-college              10
# 21490   19            Private   146679   Some-college              10
# 21875   49            Private    31267        7th-8th               4
# 22300   25            Private   195994        1st-4th               2
# 22367   44            Private   367749      Bachelors              13
# 22494   49   Self-emp-not-inc    43479   Some-college              10
# 25872   23            Private   240137        5th-6th               3
# 26313   28            Private   274679        Masters              14
# 28230   27            Private   255582        HS-grad               9
# 28522   42            Private   204235   Some-college              10
# 28846   39            Private    30916        HS-grad               9
# 29157   38            Private   207202        HS-grad               9
# 30845   46            Private   133616   Some-college              10
# 31993   19            Private   251579   Some-college              10
# 32404   35            Private   379959        HS-grad               9
#
#             marital-status          occupation    relationship
# 4881         Never-married        Craft-repair   Not-in-family  \
# 5104         Never-married       Other-service   Not-in-family
# 9171         Never-married      Prof-specialty       Own-child
# 11631        Never-married        Tech-support   Not-in-family
# 13084        Never-married     Priv-house-serv   Not-in-family
# 15059        Never-married     Farming-fishing   Not-in-family
# 17040   Married-civ-spouse        Craft-repair         Husband
# 18555        Never-married       Other-service   Not-in-family
# 18698        Never-married     Farming-fishing   Not-in-family
# 21318        Never-married        Adm-clerical       Own-child
# 21490        Never-married     Exec-managerial       Own-child
# 21875   Married-civ-spouse        Craft-repair         Husband
# 22300        Never-married     Priv-house-serv   Not-in-family
# 22367        Never-married      Prof-specialty   Not-in-family
# 22494   Married-civ-spouse        Craft-repair         Husband
# 25872        Never-married   Handlers-cleaners   Not-in-family
# 26313        Never-married      Prof-specialty   Not-in-family
# 28230        Never-married   Machine-op-inspct   Not-in-family
# 28522   Married-civ-spouse      Prof-specialty         Husband
# 28846   Married-civ-spouse        Craft-repair         Husband
# 29157   Married-civ-spouse   Machine-op-inspct         Husband
# 30845             Divorced        Adm-clerical       Unmarried
# 31993        Never-married       Other-service       Own-child
# 32404             Divorced       Other-service   Not-in-family
#
#                       race      sex   capital-gain   capital-loss
# 4881                 White     Male              0              0  \
# 5104    Asian-Pac-Islander     Male              0              0
# 9171                 White   Female              0              0
# 11631                White   Female              0              0
# 13084                White   Female              0              0
# 15059                White     Male              0              0
# 17040                White     Male              0              0
# 18555                Black     Male              0              0
# 18698                White     Male              0              0
# 21318                White   Female              0              0
# 21490                Black     Male              0              0
# 21875                White     Male              0              0
# 22300                White   Female              0              0
# 22367                White   Female              0              0
# 22494                White     Male              0              0
# 25872                White     Male              0              0
# 26313                White     Male              0              0
# 28230                White   Female              0              0
# 28522                White     Male              0              0
# 28846                White     Male              0              0
# 29157                White     Male              0              0
# 30845                White   Female              0              0
# 31993                White     Male              0              0
# 32404                White   Female              0              0
#
#         hours-per-week  native-country  income
# 4881                40          Mexico   <=50K
# 5104                35   United-States   <=50K
# 9171                10   United-States   <=50K
# 11631               10   United-States   <=50K
# 13084               40       Guatemala   <=50K
# 15059               50          Mexico   <=50K
# 17040               40   United-States   <=50K
# 18555               40               ?   <=50K
# 18698               40   United-States   <=50K
# 21318               10   United-States   <=50K
# 21490               30   United-States   <=50K
# 21875               40   United-States   <=50K
# 22300               40       Guatemala   <=50K
# 22367               45          Mexico   <=50K
# 22494               40   United-States   <=50K
# 25872               55          Mexico   <=50K
# 26313               50   United-States   <=50K
# 28230               40   United-States   <=50K
# 28522               40   United-States    >50K
# 28846               40   United-States   <=50K
# 29157               48   United-States    >50K
# 30845               40   United-States   <=50K
# 31993               14   United-States   <=50K
# 32404               40   United-States   <=50K

# %% [markdown]
# We can simply drop duplicate rows using the drop_duplicates() method.
#
# keep = ‘first’ is used to keep the first row of duplicated ones.
#
# inplace = True is used to change the data frame permanently. If we didn't use inplace attributes, we would not remove the duplicated observation from the dataset.

# %%
df.drop_duplicates(keep='first',inplace=True)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univariate Analysis
#
# The purpose of the univariate analysis is to understand the distribution of values for a single variable.
#
# We can perform univariate analysis with 3 options :
#
# 1. Summary Statistics
# 2. Frequency Distributions Table
# 3. Charts ( Boxplot, Histogram, Barplot, Pie Chart)

# %% [markdown]
# ### Univariate Analysis for Numerical Features

# %% [markdown]
# Let’s begin with sns.distplot() function. Displot stands for distribution plot and shows us distribution and kernel density estimation by default.
#
# The distribution plot shows us how our variable is distributed.

# %%
plt.figure(figsize=(10,6))
sns.distplot(df[' fnlwgt'], color='r')
plt.title('Final Weight',size=18)
plt.xlabel('Final Weight',size=14)
plt.ylabel('Density',size=14)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2632\2167236648.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[' fnlwgt'], color='r')

# %%
plt.figure(figsize=(10,6))
sns.histplot(df.age)
plt.title('Age Distribution',size=18)
plt.xlabel('Age',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df[' education-num'],color='y')
plt.title('Education Num',size=18)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df[' capital-gain'],color='g')
plt.title('Capital Gain',size=18)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df[' capital-loss'],color='r')
plt.title('capital-loss',size=18)
plt.show()

# %% [markdown]
# ### Boxplot for Numerical Values
#
# A boxplot is a standardized way of displaying the dataset based on a five-number summary: the minimum, the maximum, the sample median, and the first and third quartiles.
#
# It also helps us to detect outliers using IQR (Inter Quantile Range) method.

# %% [markdown]
# #### Age

# %%
plt.figure(figsize = (10,6))
sns.boxplot(df['age'])
plt.title('Distribution Age',size=18)
plt.show()

# %% [markdown]
# By using a boxplot, We can easily interpret our variable if it has outliers. Outliers can be easily removed from our dataset. But we reconsider before removing any of them.
#
# We need to examine or ask domain expertise if they are anomalies or not.
#
# A common way to remove outliers is to use IQR Method.

# %%
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 20.0

# %% [markdown]
# After obtaining Inter Quantile Range, we can use the IQR method to see outliers or remove them from the dataset.

# %%
df[(df['age']< Q1-1.5* IQR) | (df['age']> Q3+1.5* IQR)]
# Out:
#        age          workclass   fnlwgt      education   education-num
# 74      79            Private   124744   Some-college              10  \
# 222     90            Private    51744        HS-grad               9
# 430     80                  ?   107762        HS-grad               9
# 918     81   Self-emp-not-inc   136063        HS-grad               9
# 1040    90            Private   137018        HS-grad               9
# ...    ...                ...      ...            ...             ...
# 32277   90            Private   313749        HS-grad               9
# 32367   90          Local-gov   214594        7th-8th               4
# 32459   85            Private    98611      Bachelors              13
# 32494   82                  ?   403910        HS-grad               9
# 32525   81                  ?   120478      Assoc-voc              11
#
#             marital-status        occupation     relationship    race
# 74      Married-civ-spouse    Prof-specialty   Other-relative   White  \
# 222          Never-married     Other-service    Not-in-family   Black
# 430                Widowed                 ?    Not-in-family   White
# 918     Married-civ-spouse   Exec-managerial          Husband   White
# 1040         Never-married     Other-service    Not-in-family   White
# ...                    ...               ...              ...     ...
# 32277              Widowed      Adm-clerical        Unmarried   White
# 32367   Married-civ-spouse   Protective-serv          Husband   White
# 32459   Married-civ-spouse   Exec-managerial          Husband   White
# 32494        Never-married                 ?    Not-in-family   White
# 32525             Divorced                 ?        Unmarried   White
#
#            sex   capital-gain   capital-loss   hours-per-week  native-country
# 74        Male              0              0               20   United-States  \
# 222       Male              0           2206               40   United-States
# 430       Male              0              0               24   United-States
# 918       Male              0              0               30   United-States
# 1040    Female              0              0               40   United-States
# ...        ...            ...            ...              ...             ...
# 32277   Female              0              0               25   United-States
# 32367     Male           2653              0               40   United-States
# 32459     Male              0              0                3          Poland
# 32494     Male              0              0                3   United-States
# 32525   Female              0              0                1               ?
#
#        income
# 74      <=50K
# 222     <=50K
# 430     <=50K
# 918     <=50K
# 1040    <=50K
# ...       ...
# 32277   <=50K
# 32367   <=50K
# 32459   <=50K
# 32494   <=50K
# 32525   <=50K
#
# [142 rows x 15 columns]

# %%
df.shape[0] # number of rows
# Out:
# 32537

# %%
df.drop(df[(df['age']< Q1-1.5* IQR) | (df['age']> Q3+1.5* IQR)].index , inplace=True)

# %%
df.shape[0] # number of rows
# Out:
# 32395

# %% [markdown]
# #### Final Weight

# %%
plt.figure(figsize = (10,6))
sns.boxplot(df[' fnlwgt'])
plt.title('Distribution fnlwgt',size=18)
plt.show()

# %%
Q1 = df[' fnlwgt'].quantile(0.25)
Q3 = df[' fnlwgt'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 119433.5

# %%
df[(df[' fnlwgt']< Q1-1.5* IQR) | (df[' fnlwgt']> Q3+1.5* IQR)]
# Out:
#        age          workclass   fnlwgt      education   education-num
# 37      19            Private   544091        HS-grad               9  \
# 40      31            Private   507875            9th               5
# 80      18            Private   446839        HS-grad               9
# 110     24            Private   432376      Bachelors              13
# 157     71   Self-emp-not-inc   494223   Some-college              10
# ...    ...                ...      ...            ...             ...
# 32306   24            Private   427686        1st-4th               2
# 32329   28            Private   435842      Bachelors              13
# 32470   50            Private   485710      Doctorate              16
# 32496   18            Private   436163           11th               7
# 32511   25          Local-gov   514716      Bachelors              13
#
#             marital-status          occupation     relationship    race
# 37       Married-AF-spouse        Adm-clerical             Wife   White  \
# 40      Married-civ-spouse   Machine-op-inspct          Husband   White
# 80           Never-married               Sales    Not-in-family   White
# 110          Never-married               Sales   Other-relative   White
# 157              Separated               Sales        Unmarried   Black
# ...                    ...                 ...              ...     ...
# 32306   Married-civ-spouse   Handlers-cleaners   Other-relative   White
# 32329   Married-civ-spouse     Exec-managerial          Husband   White
# 32470             Divorced      Prof-specialty    Not-in-family   White
# 32496        Never-married      Prof-specialty        Own-child   White
# 32511        Never-married        Adm-clerical        Own-child   Black
#
#            sex   capital-gain   capital-loss   hours-per-week  native-country
# 37      Female              0              0               25   United-States  \
# 40        Male              0              0               43   United-States
# 80        Male              0              0               30   United-States
# 110       Male              0              0               40   United-States
# 157       Male              0           1816                2   United-States
# ...        ...            ...            ...              ...             ...
# 32306     Male              0              0               40          Mexico
# 32329     Male              0              0               40   United-States
# 32470   Female              0              0               50   United-States
# 32496     Male              0              0               20   United-States
# 32511   Female              0              0               40   United-States
#
#        income
# 37      <=50K
# 40      <=50K
# 80      <=50K
# 110     <=50K
# 157     <=50K
# ...       ...
# 32306   <=50K
# 32329   <=50K
# 32470   <=50K
# 32496   <=50K
# 32511   <=50K
#
# [981 rows x 15 columns]

# %% [markdown]
# #### education-num

# %%
plt.figure(figsize = (10,6))
sns.boxplot(df[' education-num'])
plt.title('Distribution education-num',size=18)
plt.show()

# %%
Q1 = df[' education-num'].quantile(0.25)
Q3 = df[' education-num'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 3.0

# %%
df[(df[' education-num']< Q1-1.5* IQR) | (df[' education-num']> Q3+1.5* IQR)]
# Out:
#        age   workclass   fnlwgt   education   education-num
# 15      34     Private   245487     7th-8th               4  \
# 56      46     Private   216666     5th-6th               3
# 61      32           ?   293936     7th-8th               4
# 79      31   Local-gov   125927     7th-8th               4
# 160     68           ?    38317     1st-4th               2
# ...    ...         ...      ...         ...             ...
# 32431   51     Private   274502     7th-8th               4
# 32432   36     Private   208068   Preschool               1
# 32448   61     Private   137554     7th-8th               4
# 32479   64   State-gov   222966     7th-8th               4
# 32517   36     Private   131459     7th-8th               4
#
#                marital-status          occupation    relationship
# 15         Married-civ-spouse    Transport-moving         Husband  \
# 56         Married-civ-spouse   Machine-op-inspct         Husband
# 61      Married-spouse-absent                   ?   Not-in-family
# 79         Married-civ-spouse     Farming-fishing         Husband
# 160                  Divorced                   ?   Not-in-family
# ...                       ...                 ...             ...
# 32431                Divorced   Machine-op-inspct   Not-in-family
# 32432                Divorced       Other-service   Not-in-family
# 32448      Married-civ-spouse        Craft-repair         Husband
# 32479      Married-civ-spouse       Other-service            Wife
# 32517      Married-civ-spouse        Craft-repair         Husband
#
#                       race      sex   capital-gain   capital-loss
# 15      Amer-Indian-Eskimo     Male              0              0  \
# 56                   White     Male              0              0
# 61                   White     Male              0              0
# 79                   White     Male              0              0
# 160                  White   Female              0              0
# ...                    ...      ...            ...            ...
# 32431                White   Female              0              0
# 32432                Other     Male              0              0
# 32448                White     Male              0              0
# 32479                Black   Female              0              0
# 32517                White     Male              0              0
#
#         hours-per-week  native-country  income
# 15                  45          Mexico   <=50K
# 56                  40          Mexico   <=50K
# 61                  40               ?   <=50K
# 79                  40   United-States   <=50K
# 160                 20   United-States   <=50K
# ...                ...             ...     ...
# 32431               48   United-States   <=50K
# 32432               72          Mexico   <=50K
# 32448               40   United-States   <=50K
# 32479               40   United-States   <=50K
# 32517               40   United-States   <=50K
#
# [1172 rows x 15 columns]

# %% [markdown]
# #### capital-gain

# %%
plt.figure(figsize = (10,6))
sns.boxplot(df[' capital-gain'])
plt.title('Distribution capital-gain',size=18)
plt.show()

Q1 = df[' capital-gain'].quantile(0.25)
Q3 = df[' capital-gain'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)

df[(df[' capital-gain']< Q1-1.5* IQR) | (df[' capital-gain']> Q3+1.5* IQR)]
# Out:
# 0.0
#        age          workclass   fnlwgt     education   education-num
# 0       39          State-gov    77516     Bachelors              13  \
# 8       31            Private    45781       Masters              14
# 9       42            Private   159449     Bachelors              13
# 59      30            Private   188146       HS-grad               9
# 60      30            Private    59496     Bachelors              13
# ...    ...                ...      ...           ...             ...
# 32515   66        Federal-gov    47358          10th               6
# 32518   57          Local-gov   110417       HS-grad               9
# 32538   38            Private   139180     Bachelors              13
# 32548   65   Self-emp-not-inc    99359   Prof-school              15
# 32560   52       Self-emp-inc   287927       HS-grad               9
#
#             marital-status          occupation    relationship    race
# 0            Never-married        Adm-clerical   Not-in-family   White  \
# 8            Never-married      Prof-specialty   Not-in-family   White
# 9       Married-civ-spouse     Exec-managerial         Husband   White
# 59      Married-civ-spouse   Machine-op-inspct         Husband   White
# 60      Married-civ-spouse               Sales         Husband   White
# ...                    ...                 ...             ...     ...
# 32515   Married-civ-spouse        Craft-repair         Husband   White
# 32518   Married-civ-spouse        Craft-repair         Husband   White
# 32538             Divorced      Prof-specialty       Unmarried   Black
# 32548        Never-married      Prof-specialty   Not-in-family   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex   capital-gain   capital-loss   hours-per-week  native-country
# 0         Male           2174              0               40   United-States  \
# 8       Female          14084              0               50   United-States
# 9         Male           5178              0               40   United-States
# 59        Male           5013              0               40   United-States
# 60        Male           2407              0               40   United-States
# ...        ...            ...            ...              ...             ...
# 32515     Male           3471              0               40   United-States
# 32518     Male          99999              0               40   United-States
# 32538   Female          15020              0               45   United-States
# 32548     Male           1086              0               60   United-States
# 32560   Female          15024              0               40   United-States
#
#        income
# 0       <=50K
# 8        >50K
# 9        >50K
# 59      <=50K
# 60      <=50K
# ...       ...
# 32515   <=50K
# 32518    >50K
# 32538    >50K
# 32548   <=50K
# 32560    >50K
#
# [2692 rows x 15 columns]

# %% [markdown]
# #### capital-loss

# %%
plt.figure(figsize = (10,6))
sns.boxplot(df[' capital-loss'])
plt.title('Distribution capital-loss',size=18)
plt.show()

Q1 = df[' capital-loss'].quantile(0.25)
Q3 = df[' capital-loss'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)

df[(df[' capital-loss']< Q1-1.5* IQR) | (df[' capital-loss']> Q3+1.5* IQR)]
# Out:
# 0.0
#        age          workclass   fnlwgt      education   education-num
# 23      43            Private   117037           11th               7  \
# 32      45            Private   386940      Bachelors              13
# 52      47            Private    51835    Prof-school              15
# 93      30            Private   117747        HS-grad               9
# 96      48   Self-emp-not-inc   191277      Doctorate              16
# ...    ...                ...      ...            ...             ...
# 32441   53            Private   304504   Some-college              10
# 32443   18            Private    41381        HS-grad               9
# 32445   61            Private   190682        HS-grad               9
# 32458   36            Private   237943      Bachelors              13
# 32500   34            Private    60567           11th               7
#
#             marital-status         occupation    relationship
# 23      Married-civ-spouse   Transport-moving         Husband  \
# 32                Divorced    Exec-managerial       Own-child
# 52      Married-civ-spouse     Prof-specialty            Wife
# 93      Married-civ-spouse              Sales            Wife
# 96      Married-civ-spouse     Prof-specialty         Husband
# ...                    ...                ...             ...
# 32441   Married-civ-spouse   Transport-moving         Husband
# 32443        Never-married              Sales       Own-child
# 32445              Widowed       Craft-repair   Not-in-family
# 32458   Married-civ-spouse     Prof-specialty         Husband
# 32500             Divorced   Transport-moving       Unmarried
#
#                       race      sex   capital-gain   capital-loss
# 23                   White     Male              0           2042  \
# 32                   White     Male              0           1408
# 52                   White   Female              0           1902
# 93      Asian-Pac-Islander   Female              0           1573
# 96                   White     Male              0           1902
# ...                    ...      ...            ...            ...
# 32441                White     Male              0           1887
# 32443                White   Female              0           1602
# 32445                Black   Female              0           1669
# 32458                White     Male              0           1977
# 32500                White     Male              0            880
#
#         hours-per-week  native-country  income
# 23                  40   United-States   <=50K
# 32                  40   United-States   <=50K
# 52                  60        Honduras    >50K
# 93                  35               ?   <=50K
# 96                  60   United-States    >50K
# ...                ...             ...     ...
# 32441               45   United-States    >50K
# 32443               20   United-States   <=50K
# 32445               50   United-States   <=50K
# 32458               45   United-States    >50K
# 32500               60   United-States   <=50K
#
# [1512 rows x 15 columns]

# %% [markdown]
# #### hours-per-week

# %%
plt.figure(figsize = (10,6))
sns.boxplot(df[' hours-per-week'])
plt.title('Distribution hours-per-week',size=18)
plt.show()

Q1 = df[' hours-per-week'].quantile(0.25)
Q3 = df[' hours-per-week'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)

df[(df[' hours-per-week']< Q1-1.5* IQR) | (df[' hours-per-week']> Q3+1.5* IQR)]
# Out:
# 5.0
#        age          workclass   fnlwgt      education   education-num
# 1       50   Self-emp-not-inc    83311      Bachelors              13  \
# 6       49            Private   160187            9th               5
# 10      37            Private   280464   Some-college              10
# 12      23            Private   122272      Bachelors              13
# 20      40            Private   193524      Doctorate              16
# ...    ...                ...      ...            ...             ...
# 32544   31            Private   199655        Masters              14
# 32545   39          Local-gov   111499     Assoc-acdm              12
# 32548   65   Self-emp-not-inc    99359    Prof-school              15
# 32553   32            Private   116138        Masters              14
# 32559   22            Private   201490        HS-grad               9
#
#                marital-status        occupation    relationship
# 1          Married-civ-spouse   Exec-managerial         Husband  \
# 6       Married-spouse-absent     Other-service   Not-in-family
# 10         Married-civ-spouse   Exec-managerial         Husband
# 12              Never-married      Adm-clerical       Own-child
# 20         Married-civ-spouse    Prof-specialty         Husband
# ...                       ...               ...             ...
# 32544                Divorced     Other-service   Not-in-family
# 32545      Married-civ-spouse      Adm-clerical            Wife
# 32548           Never-married    Prof-specialty   Not-in-family
# 32553           Never-married      Tech-support   Not-in-family
# 32559           Never-married      Adm-clerical       Own-child
#
#                       race      sex   capital-gain   capital-loss
# 1                    White     Male              0              0  \
# 6                    Black   Female              0              0
# 10                   Black     Male              0              0
# 12                   White   Female              0              0
# 20                   White     Male              0              0
# ...                    ...      ...            ...            ...
# 32544                Other   Female              0              0
# 32545                White   Female              0              0
# 32548                White     Male           1086              0
# 32553   Asian-Pac-Islander     Male              0              0
# 32559                White     Male              0              0
#
#         hours-per-week  native-country  income
# 1                   13   United-States   <=50K
# 6                   16         Jamaica   <=50K
# 10                  80   United-States    >50K
# 12                  30   United-States   <=50K
# 20                  60   United-States    >50K
# ...                ...             ...     ...
# 32544               30   United-States   <=50K
# 32545               20   United-States    >50K
# 32548               60   United-States   <=50K
# 32553               11          Taiwan   <=50K
# 32559               20   United-States   <=50K
#
# [8913 rows x 15 columns]

# %% [markdown]
# ### Univariate Analysis for Categorical Features
#
# A bar chart is commonly used to visualize categorical features.

# %% [markdown]
# #### workclass

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = ' workclass', data = df)
plt.title('workclass',size=18)
plt.xlabel('workclass',size=14)
plt.show()

df[' workclass'].value_counts()
# Out:
#  workclass
#  Private             22612
#  Self-emp-not-inc     2516
#  Local-gov            2084
#  ?                    1801
#  State-gov            1297
#  Self-emp-inc         1106
#  Federal-gov           958
#  Without-pay            14
#  Never-worked            7
# Name: count, dtype: int64

# %% [markdown]
# #### education

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = ' education', data = df)
plt.title('education',size=18)
plt.xlabel('education',size=14)
plt.xticks(rotation=45)
plt.show()

df[' education'].value_counts()
# Out:
#  education
#  HS-grad         10445
#  Some-college     7266
#  Bachelors        5336
#  Masters          1713
#  Assoc-voc        1377
#  11th             1171
#  Assoc-acdm       1064
#  10th              929
#  7th-8th           631
#  Prof-school       569
#  9th               512
#  12th              432
#  Doctorate         409
#  5th-6th           329
#  1st-4th           162
#  Preschool          50
# Name: count, dtype: int64

# %% [markdown]
# #### marital-status

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = ' marital-status', data = df)
plt.title('marital-status',size=18)
plt.xlabel('marital-status',size=14)
# plt.xticks(rotation=45)
plt.show()

df[' marital-status'].value_counts()
# Out:
#  marital-status
#  Married-civ-spouse       14902
#  Never-married            10648
#  Divorced                  4435
#  Separated                 1023
#  Widowed                    948
#  Married-spouse-absent      416
#  Married-AF-spouse           23
# Name: count, dtype: int64

# %% [markdown]
# #### occupation

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = ' occupation', data = df)
plt.title('occupation',size=18)
plt.xlabel('occupation',size=14)
plt.xticks(rotation=45)
plt.show()

df[' occupation'].value_counts()
# Out:
#  occupation
#  Prof-specialty       4116
#  Craft-repair         4089
#  Exec-managerial      4043
#  Adm-clerical         3756
#  Sales                3635
#  Other-service        3279
#  Machine-op-inspct    1997
#  ?                    1808
#  Transport-moving     1595
#  Handlers-cleaners    1367
#  Farming-fishing       982
#  Tech-support          927
#  Protective-serv       647
#  Priv-house-serv       145
#  Armed-Forces            9
# Name: count, dtype: int64

# %% [markdown]
# #### relationship

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = ' relationship', data = df)
plt.title('relationship',size=18)
plt.xlabel('relationship',size=14)
# plt.xticks(rotation=45)
plt.show()

df[' relationship'].value_counts()
# Out:
#  relationship
#  Husband           13124
#  Not-in-family      8238
#  Own-child          5058
#  Unmarried          3433
#  Wife               1564
#  Other-relative      978
# Name: count, dtype: int64

# %% [markdown]
# #### race

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = ' race', data = df)
plt.title('race',size=18)
plt.xlabel('race',size=14)
# plt.xticks(rotation=45)
plt.show()

df[' race'].value_counts()
# Out:
#  race
#  White                 27666
#  Black                  3115
#  Asian-Pac-Islander     1034
#  Amer-Indian-Eskimo      309
#  Other                   271
# Name: count, dtype: int64

# %% [markdown]
# #### sex

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = ' sex', data = df)
plt.title('sex',size=18)
plt.xlabel('sex',size=14)
# plt.xticks(rotation=45)
plt.show()

df[' sex'].value_counts()
# Out:
#  sex
#  Male      21676
#  Female    10719
# Name: count, dtype: int64

# %% [markdown]
# #### native-country

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = ' native-country', data = df)
plt.title('native-country',size=18)
plt.xlabel('native-country',size=14)
plt.xticks(rotation=90)
plt.show()

df[' native-country'].value_counts()
# Out:
#  native-country
#  United-States                 29027
#  Mexico                          638
#  ?                               579
#  Philippines                     197
#  Germany                         137
#  Canada                          120
#  Puerto-Rico                     113
#  El-Salvador                     105
#  India                           100
#  Cuba                             94
#  England                          89
#  Jamaica                          81
#  South                            79
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Japan                            62
#  Guatemala                        62
#  Columbia                         59
#  Poland                           57
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          27
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Scotland                         12
#  Hungary                          12
#  Holand-Netherlands                1
# Name: count, dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Bivariate analysis is the analysis of exactly two variables. We will use bivariate analysis to find relationships between two variables.
#
# For bivariate analysis, we usually use boxplot(categorical vs numerical), scatterplot(numerical vs numerical), or contingency table(categorical vs categorical).

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x=' education',y=' education-num',color='r',data=df)
plt.title('education vs education-num',size=18)
plt.xlabel('education',size=14)
plt.ylabel('education-num',size=14)
plt.show()

# %% [markdown]
# A scatterplot is a type of data display that shows the relationship between two numerical variables.

# %% [markdown]
# .corr() method also shows us the relationship between the two variables.

# %%
df.dtypes
# Out:
# age                 int64
#  workclass         object
#  fnlwgt             int64
#  education         object
#  education-num      int64
#  marital-status    object
#  occupation        object
#  relationship      object
#  race              object
#  sex               object
#  capital-gain       int64
#  capital-loss       int64
#  hours-per-week     int64
#  native-country    object
#  income            object
# dtype: object

# %%
plt.figure(figsize = (10,6))
sns.set_style('darkgrid')
sns.boxplot(x='age',y=' income',data=df)
plt.title('Age vs Income',size=18);

# %% [markdown]
# Pair plot is another awesome method that shows us the relationship between two numerical values as well as the distribution of each variable.

# %%
sns.pairplot(df, 
                 markers="+",
                 diag_kind="kde",
                 kind='reg',
                 plot_kws={'line_kws':{'color':'#aec6cf'}, 
                           'scatter_kws': {'alpha': 0.7, 
                                           'color': 'red'}},
                 corner=True);

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# ## Correlation

# %% [markdown]
# Correlation is used to test relationships between quantitative variables or categorical variables. It’s a measure of how things are related.

# %%
from sklearn.preprocessing import LabelEncoder

df = df.apply(LabelEncoder().fit_transform)

# %% [markdown]
# We will combine the .corr() method with heatmap so that we will be able to see the relationship in the graph. .corr() method is used Pearson correlation by default.

# %%
df.corr()
# Out:
#                       age   workclass    fnlwgt   education   education-num
# age              1.000000    0.009961 -0.076010   -0.007897        0.040474  \
#  workclass       0.009961    1.000000 -0.019541    0.023501        0.052528
#  fnlwgt         -0.076010   -0.019541  1.000000   -0.026891       -0.043039
#  education      -0.007897    0.023501 -0.026891    1.000000        0.357618
#  education-num   0.040474    0.052528 -0.043039    0.357618        1.000000
#  marital-status -0.282903   -0.063527  0.031846   -0.037783       -0.068076
#  occupation     -0.016773    0.252261  0.002840   -0.021600        0.109782
#  relationship   -0.267155   -0.091336  0.006910   -0.011471       -0.095362
#  race            0.028470    0.049457 -0.009736    0.014880        0.032221
#  sex             0.090351    0.096404  0.026290   -0.027247        0.012234
#  capital-gain    0.127277    0.029714 -0.004015    0.032097        0.154618
#  capital-loss    0.065114    0.015787 -0.009086    0.015870        0.084773
#  hours-per-week  0.085539    0.136699 -0.020883    0.055956        0.150094
#  native-country -0.001103   -0.007722 -0.056929    0.064221        0.051405
#  income          0.242736    0.051893 -0.010481    0.079214        0.335214
#
#                   marital-status   occupation   relationship      race
# age                    -0.282903    -0.016773      -0.267155  0.028470  \
#  workclass             -0.063527     0.252261      -0.091336  0.049457
#  fnlwgt                 0.031846     0.002840       0.006910 -0.009736
#  education             -0.037783    -0.021600      -0.011471  0.014880
#  education-num         -0.068076     0.109782      -0.095362  0.032221
#  marital-status         1.000000    -0.009074       0.185902 -0.067998
#  occupation            -0.009074     1.000000      -0.076462  0.006959
#  relationship           0.185902    -0.076462       1.000000 -0.115935
#  race                  -0.067998     0.006959      -0.115935  1.000000
#  sex                   -0.128459     0.080391      -0.582918  0.087662
#  capital-gain          -0.074932     0.025966      -0.092719  0.024597
#  capital-loss          -0.036579     0.017828      -0.064305  0.019518
#  hours-per-week        -0.191219     0.078098      -0.254575  0.042949
#  native-country        -0.024271    -0.012412      -0.005276  0.138694
#  income                -0.198880     0.075239      -0.251700  0.071849
#
#                       sex   capital-gain   capital-loss   hours-per-week
# age              0.090351       0.127277       0.065114         0.085539  \
#  workclass       0.096404       0.029714       0.015787         0.136699
#  fnlwgt          0.026290      -0.004015      -0.009086        -0.020883
#  education      -0.027247       0.032097       0.015870         0.055956
#  education-num   0.012234       0.154618       0.084773         0.150094
#  marital-status -0.128459      -0.074932      -0.036579        -0.191219
#  occupation      0.080391       0.025966       0.017828         0.078098
#  relationship   -0.582918      -0.092719      -0.064305        -0.254575
#  race            0.087662       0.024597       0.019518         0.042949
#  sex             1.000000       0.077146       0.050335         0.232653
#  capital-gain    0.077146       1.000000      -0.056970         0.101194
#  capital-loss    0.050335      -0.056970       1.000000         0.059183
#  hours-per-week  0.232653       0.101194       0.059183         1.000000
#  native-country -0.008182       0.007582       0.001110        -0.002683
#  income          0.216147       0.339637       0.163211         0.232446
#
#                   native-country    income
# age                    -0.001103  0.242736
#  workclass             -0.007722  0.051893
#  fnlwgt                -0.056929 -0.010481
#  education              0.064221  0.079214
#  education-num          0.051405  0.335214
#  marital-status        -0.024271 -0.198880
#  occupation            -0.012412  0.075239
#  relationship          -0.005276 -0.251700
#  race                   0.138694  0.071849
#  sex                   -0.008182  0.216147
#  capital-gain           0.007582  0.339637
#  capital-loss           0.001110  0.163211
#  hours-per-week        -0.002683  0.232446
#  native-country         1.000000  0.016015
#  income                 0.016015  1.000000

# %%
plt.figure(figsize = (20,9))
sns.heatmap(df.corr(),annot=True,square=True,
            cmap='RdBu',
            vmax=1,
            vmin=-1)
plt.title('Correlations Between Variables',size=18);
plt.xticks(size=13)
plt.yticks(size=13)
plt.show()
